# %% [markdown]
# # Unsung Real Estate Agency Project
#
# by: Nick Kimani

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Business Problem

# %% [markdown]
# Unsung real estate agency in King County want to  automate selection of house selling prices and by doing this, also be able to advise their customers on the do's and don'ts to making their houses more valueable.

# %%
import pandas as pd


data = pd.read_csv('/home/nick/Documents/Flatiron/Phase 2/Project_2/Data/Cleaned_housing.csv', index_col='Unnamed: 0')

# %%
data
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  2014-10-13   221900.0         3       1.00         1180
# 1      6414100192  2014-12-09   538000.0         3       2.25         2570
# 2      2487200875  2014-12-09   604000.0         4       3.00         1960
# 3      1954400510  2015-02-18   510000.0         3       2.00         1680
# 4      7237550310  2014-05-12  1230000.0         4       4.50         5420
# ...           ...         ...        ...       ...        ...          ...
# 17222   263000018  2014-05-21   360000.0         3       2.50         1530
# 17223  6600060120  2015-02-23   400000.0         4       2.50         2310
# 17224  1523300141  2014-06-23   402101.0         2       0.75         1020
# 17225   291310100  2015-01-16   400000.0         3       2.50         1600
# 17226  1523300157  2014-10-15   325000.0         2       0.75         1020
#
# ...
