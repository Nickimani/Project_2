# %% [markdown]
# # Unsung Real Estate Agency Project
#
# _by: Nick Kimani_

# %% [markdown]
# ## Business Problem
#
# Unsung real estate agency is an agency in King County that deals with clients who want to buy/sell homes.
#
# They want to create an algorithm and use it to make a model for pricing of houses:
# - The primary purpose of the model is to predict buying/selling prices of houses.
# - The secondary purpose is for inferring features/atrributes that significantly affect the pricing of a house.
#
# By completing this, the business is at a better position to advise clients who want to buy/sell homes with factual information about homes, their costs or selling prices and exactly why their prices are as they are.

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Data Summary
#
# The data used is for the for the year 2014 May - 2015 May. The data has no missing records or inappropriate datatypes. There are 21597 records of homes in King County, their attributes, renovation year if any, and their selling price. This is significant information to use for modelling and inferencing in line with  our business problem.
#
# For our model:
# - The target is __`price`__ which is the pricing/value of a house.
# - `sqft_lot` is the area of the whole plot of land.
# - `sqft_living` is the area which the house/home takes in the plot.
# - `floors` are the levels in a house.
# - `waterfront` is whether a house has a view of a waterfront or not.
# - `bedrooms`and `bathrooms` are the number of the respective rooms in a house.
# - `condition` is the overall condition of a house.
# - `grade` is the grading of a house.

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('bmh')

# %%
# Loading Data
data = pd.read_csv('/home/nick/Documents/Flatiron/Phase 2/Project_2/Data/Cleaned_housing.csv', index_col='Unnamed: 0')

# %% [markdown]
# ## Exploring and cleaning the data

# %%
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  2014-10-13  221900.0         3        1.0         1180
# 1  6414100192  2014-12-09  538000.0         3        2.0         2570
# 2  5631500400  2015-02-25  180000.0         2        1.0          770
# 3  2487200875  2014-12-09  604000.0         4        3.0         1960
# 4  1954400510  2015-02-18  510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         0.0   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  float64
#  9   view           21597 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  float64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(12), object(1)
# memory usage: 3.6+ MB

# %% [markdown]
# ### Univariate analysis

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      1.750660   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.734042    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.000000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.000000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.000000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.000000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.445988      0.006760      0.233181      3.409825
# std    4.141264e+04      0.551658      0.081944      0.764673      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.000000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.000000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21597.000000  21597.000000   21597.000000  21597.000000  21597.000000
# mean       7.657915   1788.596842     285.716581   1970.999676     68.758207
# std        1.173200    827.759761     439.819830     29.375234    364.037499
# min        3.000000    370.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     550.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000  21597.000000   21597.000000   21597.000000
# mean   98077.951845     47.560093   -122.213982    1986.620318   12758.283512
# std       53.513072      0.138552      0.140724     685.230472   27274.441950
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471100   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.231000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# We observe that:
# - The avarage price of a house in King county is 540296.6 dollars
# - The avarage bedroom count is 3 and maximum is 33
# - The avarage bathroom count is 2 and maximum is 8
# - The avarage sqft_living area is 2080.32185
# - The avarage sqft_lot area is 15099.41
# - The avarage floor(s) in a house is 1 and maximum is 3
# - Most houses don't have waterfronts
# - Most houses have not been viewed
# - The avarage condition of houses is 3 on a scale of 1-5
# - The avarage grade of a house is 7 on a scale of 3-13
# -

# %% [markdown]
# Plot histograms for all numeric columns

# %%
def Hist_plot(data, column):
    """
    A function that does a histogram for the column specified in a given dataframe
    """
    # Set number of bins depending on max value in the column
    if data[column].max() < 1000:
        # Plot hist without bins specifications
        fig, ax = plt.subplots(figsize=(8, 5))    
        ax.hist(data[column])
        
        ax.set_xlabel(column)
        ax.set_ylabel('Count')
        ax.set_title(f'{column.title()} histogram')
        plt.savefig(f'/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/{column.title()} histogram.jpg')
        plt.show()
        
    elif data[column].max() < 1000:
        # Plot hist with 100 bins 
        fig, ax = plt.subplots(figsize=(8, 5))    
        ax.hist(data[column], bins=100)
        
        ax.set_xlabel(column)
        ax.set_ylabel('Count') 
        ax.set_title(f'{column.title()} histogram')
        plt.savefig(f'/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/{column.title()} histogram.jpg')
        plt.show()
        
    else:
        # Plot hist with 200 bins 
        fig, ax = plt.subplots(figsize=(8, 5))    
        ax.hist(data[column], bins=100, align='mid')
        
        ax.set_xlabel(column)
        ax.set_ylabel('Count')
        ax.set_title(f'{column.title()} histogram')
        plt.savefig(f'/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/{column.title()} histogram.jpg')
        plt.show()

# %%
# Make a list of columns that don't make sense looking for outliers 
# also price as its too early to deal with it
irr_cols = ['long', 'lat', 'zipcode', 'id']

# Create a for loop to loop through our function for plotting
for column in data.columns:
    if data[column].dtype == 'int64' or data[column].dtype == 'float64':
        if column not in irr_cols:
            # call the function
            Hist_plot(data, column)
        
    else:
        continue

# %% [markdown]
# We can observe that the categorical columns are:
# - bedrooms
# - bathrooms
# - floors
# - waterfront
# - view
# - condition
# - grade

# %%
data['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
data['bathrooms'].value_counts()
# Out:
# 2.0    10539
# 1.0     8353
# 3.0     2228
# 4.0      338
# 0.0       75
# 5.0       48
# 6.0       12
# 7.0        2
# 8.0        2
# Name: bathrooms, dtype: int64

# %%
data['floors'].value_counts()
# Out:
# 1.0    12583
# 2.0     8396
# 3.0      618
# Name: floors, dtype: int64

# %%
data['waterfront'].value_counts()
# Out:
# 0.0    21451
# 1.0      146
# Name: waterfront, dtype: int64

# %%
data['view'].value_counts()
# Out:
# 0.0    19485
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %%
data['condition'].value_counts()
# Out:
# 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: condition, dtype: int64

# %%
data['grade'].value_counts()
# Out:
# 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %% [markdown]
# Columns with continuous variable columns are:
# - price
# - sqft_living
# - sqft_lot
# - sqft_above
# - sqft_basement
# - yr_built
# - sqft_living15
# - sqft_lot15

# %% [markdown]
# #### Dealing with outliers

# %%
def Box_plot(data, column):
    """
    A function that does a boxplot for the column specified in a given dataframe
    """
    fig, ax = plt.subplots(figsize=(8, 5))
    
    data[column].plot(kind='box', ax=ax, title=f'{column.title()} boxplot')
    
    ax.set_ylabel(column)
    plt.savefig(f'/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/{column.title()} boxplot.jpg')
    plt.show()

# %%
# Create a for loop to loop through our function for plotting
for column in data.columns:
    if data[column].dtype == 'int64' or data[column].dtype == 'float64':
        if column not in irr_cols:
            # call the function
            Box_plot(data, column)
        
    else:
        continue

# %% [markdown]
# Comments on outliers:
# - Looks like there are outliers in bedrooms column

# %%
data['bedrooms'].sort_values(ascending=False).head()
# Out:
# 15856    33
# 8748     11
# 19239    10
# 13301    10
# 15147    10
# Name: bedrooms, dtype: int64

# %%
# 33 is the outlier.
# Drop the row containing it
data = data[data['bedrooms'] != 33]

# %% [markdown]
# #### Creating, editing and dropping columns

# %%
def Drop_columns(data, columns):
    "This function takes in a list of columns that you want to drop from a dataframe and the dataframe itself"
    data.drop(columns=columns, inplace=True)

# %% [markdown]
# ##### Checking columns that could contain information about homes in a neighbourhood

# %% [markdown]
# Compare to the sqft_living15 and sqft_lot15 columns in our data as these columns have something to do with neighbourhoods.

# %%
data[['sqft_living', 'sqft_living15', 'sqft_lot', 'sqft_lot15']]
# Out:
#        sqft_living  sqft_living15  sqft_lot  sqft_lot15
# 0             1180           1340      5650        5650
# 1             2570           1690      7242        7639
# 2              770           2720     10000        8062
# 3             1960           1360      5000        5000
# 4             1680           1800      8080        7503
# ...            ...            ...       ...         ...
# 21592         1530           1530      1131        1509
# 21593         2310           1830      5813        7200
# 21594         1020           1020      1350        2007
# 21595         1600           1410      2388        1287
# 21596         1020           1020      1076        1357
#
# [21596 rows x 4 columns]

# %% [markdown]
# I can't make sense of sqft_living15 and sqft_lot15 columns so I am going to drop them.

# %%
Drop_columns(data, ['sqft_lot15', 'sqft_living15'])

# %% [markdown]
# ##### Create month_sold and year_sold  columns

# %% [markdown]
# The date column contains dates that homes were bought and wouldn't be of much help as it is. The column would be better represented as:
# - months of the year(month_sold) and
# - year(year_sold)
#
# The middle set of numbers in the date records represent month while the first set represent the year.

# %%
data.date.head()
# Out:
# 0    2014-10-13
# 1    2014-12-09
# 2    2015-02-25
# 3    2014-12-09
# 4    2015-02-18
# Name: date, dtype: object

# %%
# Selecting the month indicator in date column
data['month_sold'] = [date[5:7] for date in data['date']]
data['year_sold'] = [date[0:4] for date in data['date']]

# Convert month data type to int
data.month_sold = data.month_sold.astype(int)
data.year_sold = data.year_sold.astype(int)

# Drop date column
Drop_columns(data, ['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21596 entries, 0 to 21596
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21596 non-null  int64
#  1   price          21596 non-null  float64
#  2   bedrooms       21596 non-null  int64
#  3   bathrooms      21596 non-null  float64
#  4   sqft_living    21596 non-null  int64
#  5   sqft_lot       21596 non-null  int64
#  6   floors         21596 non-null  float64
#  7   waterfront     21596 non-null  float64
#  8   view           21596 non-null  float64
#  9   condition      21596 non-null  int64
#  10  grade          21596 non-null  int64
#  11  sqft_above     21596 non-null  int64
#  12  sqft_basement  21596 non-null  float64
#  13  yr_built       21596 non-null  int64
#  14  yr_renovated   21596 non-null  int64
#  15  zipcode        21596 non-null  int64
#  16  lat            21596 non-null  float64
#  17  long           21596 non-null  float64
#  18  month_sold     21596 non-null  int64
#  19  year_sold      21596 non-null  int64
# dtypes: float64(8), int64(12)
# memory usage: 3.5 MB

# %% [markdown]
# ##### Create selling_age column

# %% [markdown]
# This is the age of a house at the time it is being sold.
#
#     selling_age = year_sold - yr_built

# %%
data['selling_age'] = data['year_sold'] - data['yr_built']

# %% [markdown]
# ##### Create renovation_age column

# %% [markdown]
# This is the age of a house when the renovation is done.
#
#     renovation_age = yr_renovated - yr_built

# %%
data['renovation_age'] = data['yr_renovated'] - data['yr_built']
data['renovation_age'].head()
# Out:
# 0   -1955
# 1      40
# 2   -1933
# 3   -1965
# 4   -1987
# Name: renovation_age, dtype: int64

# %% [markdown]
# Take care of negative values in the new column. Those records are the houses that have no renovations. Set them as 0 indicating no renovation has been done.

# %%
# Replace all negative values with 0
data['renovation_age'] = [y if y > 0 else 0 for y in data['renovation_age']]

# %% [markdown]
# ##### Create sold_renovation column

# %% [markdown]
# This is the age in years a house is being sold after renovation.
#
#     sold_renovation = year_sold - yr_renovated

# %%
data['sold_renovation'] = data['year_sold'] - data['yr_renovated']

# %%
data['sold_renovation']
# Out:
# 0        2014
# 1          23
# 2        2015
# 3        2014
# 4        2015
#          ...
# 21592    2014
# 21593    2015
# 21594    2014
# 21595    2015
# 21596    2014
# Name: sold_renovation, Length: 21596, dtype: int64

# %% [markdown]
# Take care of the records that didn't have any renovations done

# %%
# Replace all values greater than 1000
# Values past 1000 are for the homes that have no renovations done
data['sold_renovation'] = [y if y < 1000 else 0 for y in data['sold_renovation']]

# %%
data['sold_renovation']
# Out:
# 0         0
# 1        23
# 2         0
# 3         0
# 4         0
#          ..
# 21592     0
# 21593     0
# 21594     0
# 21595     0
# 21596     0
# Name: sold_renovation, Length: 21596, dtype: int64

# %%
data.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3        1.0         1180      5650     1.0
# 1  6414100192  538000.0         3        2.0         2570      7242     2.0
# 2  5631500400  180000.0         2        1.0          770     10000     1.0
# 3  2487200875  604000.0         4        3.0         1960      5000     1.0
# 4  1954400510  510000.0         3        2.0         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0         0.0   0.0          3  ...      1955             0    98178  47.5112
# 1         0.0   0.0          3  ...      1951          1991    98125  47.7210
# 2         0.0   0.0          3  ...      1933             0    98028  47.7379
# 3         0.0   0.0          5  ...      1965             0    98136  47.5208
# 4         0.0   0.0          3  ...      1987             0    98074  47.6168
#
#       long  month_sold  year_sold  selling_age  renovation_age  \
# 0 -122.257          10       2014           59               0
# 1 -122.319          12       2014           63              40
# 2 -122.233           2       2015           82               0
# 3 -122.393          12       2014           49               0
# 4 -122.045           2       2015           28               0
#
#    sold_renovation
# 0                0
# 1               23
# 2                0
# 3                0
# 4                0
#
# [5 rows x 23 columns]

# %% [markdown]
# ##### Editing(Rescaling) grade column
#
# The scale is 3 - 13 which is a harder to interepret compared to a 1 - 11 scale.

# %%
data['grade'].replace({3:1, 4:2, 5:3, 6:4, 7:5, 8:6, 9:7, 10:8, 11:9, 12:10, 13:11}, inplace=True)

# %%
data['grade'].unique()
# Out:
# array([ 5,  4,  6,  9,  7,  3,  8, 10,  2,  1, 11])

# %% [markdown]
# ##### Dropping sqft_above and sqft_basement columns

# %%
# Checking whether the relationship of columns is as I suspect
pd.DataFrame(data['sqft_living'] == data['sqft_above'] + data['sqft_basement']).value_counts()
# Out:
# True     21426
# False      170
# dtype: int64

# %% [markdown]
# Based on this it would be safe to assume that sqft_living is the summation of sqft_basement and sqft_above.
#
# This means we can do without the latter two columns.

# %%
# Drop the two columns
Drop_columns(data, ['sqft_basement', 'sqft_above'])

data.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3        1.0         1180      5650     1.0
# 1  6414100192  538000.0         3        2.0         2570      7242     2.0
# 2  5631500400  180000.0         2        1.0          770     10000     1.0
# 3  2487200875  604000.0         4        3.0         1960      5000     1.0
# 4  1954400510  510000.0         3        2.0         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0         0.0   0.0          3  ...      1955             0    98178  47.5112
# 1         0.0   0.0          3  ...      1951          1991    98125  47.7210
# 2         0.0   0.0          3  ...      1933             0    98028  47.7379
# 3         0.0   0.0          5  ...      1965             0    98136  47.5208
# 4         0.0   0.0          3  ...      1987             0    98074  47.6168
#
#       long  month_sold  year_sold  selling_age  renovation_age  \
# 0 -122.257          10       2014           59               0
# 1 -122.319          12       2014           63              40
# 2 -122.233           2       2015           82               0
# 3 -122.393          12       2014           49               0
# 4 -122.045           2       2015           28               0
#
#    sold_renovation
# 0                0
# 1               23
# 2                0
# 3                0
# 4                0
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Dropping other columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21596 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21596 non-null  int64
#  1   price            21596 non-null  float64
#  2   bedrooms         21596 non-null  int64
#  3   bathrooms        21596 non-null  float64
#  4   sqft_living      21596 non-null  int64
#  5   sqft_lot         21596 non-null  int64
#  6   floors           21596 non-null  float64
#  7   waterfront       21596 non-null  float64
#  8   view             21596 non-null  float64
#  9   condition        21596 non-null  int64
#  10  grade            21596 non-null  int64
#  11  yr_built         21596 non-null  int64
#  12  yr_renovated     21596 non-null  int64
#  13  zipcode          21596 non-null  int64
#  14  lat              21596 non-null  float64
#  15  long             21596 non-null  float64
#  16  month_sold       21596 non-null  int64
#  17  year_sold        21596 non-null  int64
#  18  selling_age      21596 non-null  int64
#  19  renovation_age   21596 non-null  int64
#  20  sold_renovation  21596 non-null  int64
# dtypes: float64(7), int64(14)
# memory usage: 3.6 MB

# %% [markdown]
# Dropping:
# - yr_renovated as it has been accounted for in other ways.
# - id, lat, and long because I don't see them helping.

# %%
Drop_columns(data, ['yr_renovated', 'id', 'lat', 'long'])

# %% [markdown]
# #### Check the distribution of price(target)

# %%
# Check out the distribution of our target
fig, ax = plt.subplots(ncols=2, figsize=(12, 9), )
fig.set_tight_layout(True)

# histogram
ax[0].hist(data['price'], bins=250, density=True, align='left', color='r', )
ax[0].set_ylabel('Density')
ax[0].set_xlabel('Price')

# Cumulative 
sns.kdeplot(data['price'], ax=ax[1], cumulative=True)
ax[1].set_ylabel('Density')
ax[1].set_xlabel('Price')

fig.suptitle('Distribution of Price(target)')
plt.savefig('/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/Price distribution.jpg')
plt.show()

# %% [markdown]
# #### Check the distribution of the columns again

# %%
# Create a for loop to loop through our function for plotting
for column in data.columns:
    # call the function
    Hist_plot(data, column)

# %% [markdown]
# ##### Distribution Interpretation

# %% [markdown]
# `price` - Most homes are priced between 78000 dollars and 1 million dollars. The values past 3 million are very little in number
#
# `bedrooms` 'n' `bathrooms` - Most homes have 3 bedrooms and 2 bathrooms
#
# `sqft_living` - Most homes have an area of 370 - 4000 sqft
#
# `floors` - Most homes are 1 storey structured
#
# `waterfront` - Most homes don't have a waterfront view
#
# `view` - Most homes have not been viewed
#
# `condition` - Most homes have a rating of 3 out of 5
#
# `grade` - Most homes are rated 5 on a scale of 3 - 13
#
# `yr_built` - The number of houses built per year from 1900 have increased gradually, with most homes being built in 2001 to 2014.
#
# `month_sold` - Most homes are sold in the month of December followed by April
#
# `selling_age` - Most homes sold are usually young(recently built). Older homes have less sales
#
# `renovation_age` - Most homes haven't been done for renovations

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ##### Price against all other columns
#
# The main focus in this section will be relationships of other columns in the data to price

# %%
X_data = data.drop(columns='price')
y_data = data['price']

# %% [markdown]
# Check out the column correlations to price:

# %%
# Empty list to store correlation values
corr_list = []

for col in X_data.columns:
    corr = data[[y_data.name, col]].corr(method='pearson')[y_data.name][1]
    corr_list.append(round(corr, 5))
    
# Matching corr values to a column name
column_corr = list(zip(X_data.columns, corr_list))

# Create a dataframe to store our values
corr_df = pd.DataFrame(column_corr, columns=['Column_name', "Corr_to_price"])
corr_df.sort_values(by='Corr_to_price', ascending=False)
# Out:
#         Column_name  Corr_to_price
# 2       sqft_living        0.70193
# 8             grade        0.66796
# 1         bathrooms        0.51066
# 6              view        0.39350
# 0          bedrooms        0.31596
# 5        waterfront        0.26431
# 4            floors        0.23728
# 14   renovation_age        0.11063
# 3          sqft_lot        0.08988
# 15  sold_renovation        0.06260
# 9          yr_built        0.05396
# 7         condition        0.03603
# 12        year_sold        0.00374
# 11       month_sold       -0.00993
# 10          zipcode       -0.05341
# 13      selling_age       -0.05390

# %%
# Create a function for plotting scatter plots
def Scatter_plot(X_data, y_data, column):
    """
    A function that does a scatterplot for the column specified in a given dataframe
    """
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.scatter(X_data[column], y_data, c='r')
        
    ax.set_xlabel(column)
    ax.set_ylabel(y_data.name) 
    ax.set_title(f'{column.title()} scatterplot')
    
    plt.savefig(f'/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/{column.title()} scatterplot.jpg')
    plt.show()

# %%
# Create a for loop to loop through our function for plotting
for column in X_data.columns:
    # call the function
    Scatter_plot(X_data, y_data, column)

# %% [markdown]
# ###### Correlation and Scatter plot Interpretation

# %% [markdown]
# The top features correlated to price are:
# - sqft_living
# - grade
# - bathrooms
# - view
# - bedrooms
#
# A bit more in-depth interpretation:
# - Bedroom price is somewhat normally distributed, with peak price hitting at 6 bedrooms and then they start dipping.
# - Price increases gradually in relation to bathroom count
# - sqft_living has a good direct proportionality with price
# - 2 floor homes generally attract a higher pricing
# - Generally more views translate to higher price
# - Condition is somewhat normally distributed with peak hitting at 3
# - The higher the grade the higher the price in general

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Here we are going to look at how columns correlate to each other with an exception of price.

# %%
# Make dataframe of correlation values 
corrs = data.drop('price', axis=1).corr()

# Set figure and axes
fig, ax = plt.subplots(figsize=(16, 10))
fig.set_tight_layout(True)

# Plot the heatmap
sns.heatmap(
    # Data for plotting
    corrs, 
    # Axis to plot on
    ax=ax, 
    # Show correlation values
    annot=True,
    # To set a diverging color gradient
    center=0,
    # Get rid of the other half of duplicates
    mask=np.triu(np.ones_like(corrs, dtype=bool)),
    # Set name of key/legend
    cbar_kws={"label": "Correlation"}
)

# Set the figure title
ax.set_title('Correlation of all features in our data(including the target)')
plt.xticks(rotation=45)

# Save the chart 
plt.savefig('/home/nick/Documents/Flatiron/Phase 2/Project_2/Images/Correlation_of_features.jpg')
plt.show()

# %% [markdown]
# We can see highly correlated features like:
#
# *Positive correlation*
# - `grade` and `sqft_living`
# - `sqft_living` and `bathrooms`
# - `grade` and `bathrooms`
# - `sqft_living` and `bedrooms`
# - `solid_renovation` and `renovation_age`
# - `yr_built` and `floors`
#
# *Negative correlation*
# - `selling_age` and `yr_built`
# - `year_sold` and `month_sold`
# - `selling_age` and `floors`

# %%
data.shape
# Out:
# (21596, 17)

# %%
# # plotting scatterplots for all columns against price
# fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(12, 8))
# fig.set_tight_layout(True)

# # Create a loop for plotting 
# for index, col in enumerate(X_train.columns):
#     ax = axes[index//5][index%5]
#     ax.scatter(X_train[col], y_train, alpha=0.3)
#     ax.set_xlabel(col)
#     ax.set_ylabel("Price")

# %%
# # Split the data
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

# # Concatenate all train  and test data for ease in processing 
# train_data = pd.concat([y_train, X_train], axis=1)
# test_data = pd.concat([y_test, X_test], axis=1)

# train_data.head()
